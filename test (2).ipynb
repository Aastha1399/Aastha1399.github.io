# %%
# try the following:
#!pip install ipywidgets==7.4.2
#!pip install bqplot

# lets import our usual stuff
import pandas as pd
import bqplot
import numpy as np
import traitlets
import ipywidgets
# %matplotlib inline

# %%
# %pip install bqplot
# Out:
# Collecting bqplot
#   Downloading bqplot-0.12.33-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: ipywidgets>=7.5.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from bqplot) (7.6.5)
# Collecting traittypes>=0.0.6
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from bqplot) (5.1.1)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from bqplot) (1.3.5)
# Requirement already satisfied: numpy<2.0.0,>=1.10.4 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from bqplot) (1.20.3)
# Requirement already satisfied: ipython>=4.0.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.5.0->bqplot) (7.29.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.5.0->bqplot) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.5.0->bqplot) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.5.0->bqplot) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.5.0->bqplot) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.5.0->bqplot) (3.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (1.5.1)
# Requirement already satisfied: appnope in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (6.1.12)
# Requirement already satisfied: pexpect>4.3 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (4.8.0)
# Requirement already satisfied: backcall in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (58.0.4)
# Requirement already satisfied: decorator in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (5.1.0)
# Requirement already satisfied: pygments in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (2.10.0)
# Requirement already satisfied: pickleshare in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (21.4.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.0.0->bqplot) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (6.4.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.12.0)
# Requirement already satisfied: nbconvert in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (6.3.0)
# Requirement already satisfied: jinja2 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (2.11.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.5.1)
# Requirement already satisfied: argon2-cffi in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.15.0)
# Requirement already satisfied: pycparser in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.1.1)
# Requirement already satisfied: defusedxml in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.7.1)
# Requirement already satisfied: testpath in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.5.0)
# Requirement already satisfied: bleach in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.5.0)
# Requirement already satisfied: async-generator in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (1.10)
# Requirement already satisfied: packaging in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (21.3)
# Requirement already satisfied: webencodings in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/aasthajain/opt/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot) (3.0.4)
# Installing collected packages: traittypes, bqplot
# Successfully installed bqplot-0.12.33 traittypes-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
data = np.random.random((10, 10))

# %%
# now add scales - colors, x & y
col_sc = bqplot.ColorScale(scheme = "Reds")
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()

# create axis - for colors, x & y
c_ax = bqplot.ColorAxis(scale = col_sc, 
                        orientation = 'vertical', 
                        side = 'right')
x_ax = bqplot.Axis(scale = x_sc)
y_ax = bqplot.Axis(scale = y_sc, 
                   orientation = 'vertical')


# so now, lets write a little function that links the data value
#  to the selected & lets print this in a little ipywidgets label
mySelectedLabel = ipywidgets.Label()

# (1) 
# lets write our linking function
# there are a few ways to link this,
#  here is a simple way first
def get_data_value(change):
    i,j = heat_map.selected[0]
    v = data[i,j] # grab data value
    mySelectedLabel.value = str(v) # set our label

# (2) this is maybe in-elegant as we are 
#  explicitly calling our origininal heat map!
#  so, lets instead remind ourselves what "change" is here
def get_data_value(change):
    print(change)
    i,j = heat_map.selected[0]
    v = data[i,j] # grab data value
    mySelectedLabel.value = str(v) # set our label
# now we see when we click we get back a whole
#  dictionary of information - if we recall, 
#  "owner" here is our heat_map which "owns" 
# this change.
#  If we want to be able to apply our function to 
#  this or any other heatmap figure we generate,
#  we can re-write the above function as follows:

# (3)
#def get_data_value(change,mylab):
def get_data_value(change):
    #print(change['owner'].selected)
    i,j = change['owner'].selected[0]
    v = data[i,j] # grab data value
    mySelectedLabel.value = str(v) # set our label
    #mylab.value = str(v) # set our label
# so, this now is applied to any map that we choose to input
    
# regenerate our heatmap to use in our fig canvas
heat_map = bqplot.GridHeatMap(color = data,
                              scales = {'color': col_sc,
                                        'row': y_sc,
                                        'column': x_sc},
                              interactions = {'click': 'select'},
                              anchor_style = {'fill':'blue'}, 
                              selected_style = {'opacity': 1.0},
                              unselected_style = {'opacity': 0.8})
    
# make sure we check out     
heat_map.observe(get_data_value, 'selected')
#heat_map.observe(self, mySelectedLabel)
fig = bqplot.Figure(marks = [heat_map], 
                    axes = [c_ax, y_ax, x_ax])

print(ipywidgets.VBox([mySelectedLabel, fig]))
# Out:
# VBox(children=(Label(value=''), Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale(scheme='Reds'), side='right'), Axis(orientation='vertical', scale=OrdinalScale()), Axis(scale=OrdinalScale())], fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, marks=[GridHeatMap(anchor_style={'fill': 'blue'}, color=array([[0.66767236, 0.53573021, 0.34824196, 0.53965156, 0.92155947,
#         0.79426341, 0.26548978, 0.88090411, 0.12896585, 0.46744419],
#        [0.96555836, 0.33658149, 0.26637191, 0.67020126, 0.22985828,
#         0.24379054, 0.13482953, 0.2372555 , 0.02233549, 0.97100121],
#        [0.17838915, 0.4725569 , 0.96896151, 0.47666161, 0.72517814,
#         0.78958804, 0.25727283, 0.27782209, 0.36978112, 0.77986475],
#        [0.09041308, 0.71102132, 0.22088859, 0.45343419, 0.61055135,
#         0.40337607, 0.10843816, 0.60279864, 0.54940381, 0.89858893],
#        [0.13144626, 0.32112668, 0.45054946, 0.85601741, 0.5950244 ,
#         0.10249235, 0.49270726, 0.46040757, 0.40469601, 0.61035506],
#        [0.10261582, 0.42064114, 0.692732  , 0.61844004, 0.25878374,
#         0.65215647, 0.1039816 , 0.25910453, 0.27940682, 0.70784592],
#        [0.64050489, 0.0673599 , 0.68701452, 0.67055978, 0.88511906,
#         0.10572353, 0.9917158 , 0.95560465, 0.0095073 , 0.5669882 ],
#        [0.80715479, 0.08655617, 0.02355324, 0.31945827, 0.61850389,
#         0.0778803 , 0.32356482, 0.73241025, 0.98315991, 0.16827281],
#        [0.19339619, 0.74305878, 0.08500953, 0.44761774, 0.40850733,
#         0.93988589, 0.88726037, 0.92331455, 0.14164507, 0.43173108],
#        [0.49403142, 0.78113162, 0.30618999, 0.9664391 , 0.36544999,
#         0.04178102, 0.21782486, 0.05600006, 0.62286083, 0.05166497]]), interactions={'click': 'select'}, scales={'color': ColorScale(scheme='Reds'), 'row': OrdinalScale(), 'column': OrdinalScale()}, scales_metadata={'row': {'orientation': 'vertical', 'dimension': 'y'}, 'column': {'orientation': 'horizontal', 'dimension': 'x'}, 'color': {'dimension': 'color'}}, selected_style={'opacity': 1.0}, tooltip_style={'opacity': 0.9}, unselected_style={'opacity': 0.8})], scale_x=LinearScale(allow_padding=False, max=1.0, min=0.0), scale_y=LinearScale(allow_padding=False, max=1.0, min=0.0))))
